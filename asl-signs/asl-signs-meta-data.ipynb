# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
from tqdm.notebook import tqdm
import os
import json
from ipywidgets import widgets
import plotly.express as px
import plotly.graph_objects as go

plt.style.use("ggplot")

# %%
competition = 'asl-signs'

iskaggle = os.environ.get('KAGGLE_KERNEL_RUN_TYPE', '')
if iskaggle:
    path = Path('..') / 'input'  / 'competition'
    # !pip install -Uqq fastai
else:
    import zipfile, kaggle
    path = Path.home() / '.data' / 'asl-signs'
    if not path.exists():
        path.mkdir(exist_ok=True)
        kaggle.api.competition_download_cli(competition, path=path)
        zipfile.ZipFile(path / f'{competition}.zip').extractall(path)

# %%
with open(path / 'sign_to_prediction_index_map.json') as f:
    sign_labels = json.load(f)

# %%
train = (pd.read_csv(path / 'train.csv')
         .assign(idx=lambda x: x.participant_id.astype(str) + '_' + x.sequence_id.astype(str))
         .set_index('idx')
        )
train.head()
# Out:
#                                                            path  \
# idx
# 26734_1000035562  train_landmark_files/26734/1000035562.parquet
# 28656_1000106739  train_landmark_files/28656/1000106739.parquet
# 16069_100015657    train_landmark_files/16069/100015657.parquet
# 25571_1000210073  train_landmark_files/25571/1000210073.parquet
# 62590_1000240708  train_landmark_files/62590/1000240708.parquet
#
#                   participant_id  sequence_id   sign
# idx
# 26734_1000035562           26734   1000035562   blow
# 28656_1000106739           28656   1000106739   wait
# 16069_100015657            16069    100015657  cloud
# 25571_1000210073           25571   1000210073   bird
# 62590_1000240708           62590   1000240708   owie

# %%
COORD_COLS = ['x', 'y', 'z']

# %% [markdown]
# # Are Any Rows Partially Populated?
#
# one of x, y or z has a value while another has a missing value

# %%
n = len(train)
for i in tqdm(range(n)):
    record = train.iloc[i]
    record_id = str(record['participant_id']) + '_' + str(record['sequence_id'])

    pq_path = path / record['path']
    try:
        landmarks = pd.read_parquet(pq_path)
    except OSError:
            train.loc[record_id, 'cnt_partial_nulls'] = np.nan
    else:
        cnt_partial_nulls = (~landmarks.loc[:, COORD_COLS].isna().all(axis=1) &
                             landmarks.loc[:, COORD_COLS].isna().any(axis=1)).sum()
        train.loc[record_id, 'cnt_partial_nulls'] = cnt_partial_nulls
# Out:
#   0%|          | 0/94477 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_92440/4288309759.py in <cell line: 2>()
#       6     pq_path = path / record['path']
#       7     try:
# ----> 8         landmarks = pd.read_parquet(pq_path)
#       9     except OSError:
#      10             train.loc[record_id, 'cnt_partial_nulls'] = np.nan
#
# ~/anaconda3/envs/fastai/lib/python3.9/site-packages/pandas/io/parquet.py in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, **kwargs)
#     491     impl = get_engine(engine)
#     492
# --> 493     return impl.read(
#     494         path,
#     495         columns=columns,
#
# ~/anaconda3/envs/fastai/lib/python3.9/site-packages/pandas/io/parquet.py in read(self, path, columns, use_nullable_dtypes, storage_options, **kwargs)
#     238         )
#     239         try:
# --> 240             result = self.api.parquet.read_table(
#     241                 path_or_handle, columns=columns, **kwargs
#     242             ).to_pandas(**to_pandas_kwargs)
#
# ~/anaconda3/envs/fastai/lib/python3.9/site-packages/pyarrow/array.pxi in pyarrow.lib._PandasConvertible.to_pandas()
#
# ~/anaconda3/envs/fastai/lib/python3.9/site-packages/pyarrow/table.pxi in pyarrow.lib.Table._to_pandas()
#
# ~/anaconda3/envs/fastai/lib/python3.9/site-packages/pyarrow/pandas_compat.py in table_to_blockmanager(options, table, categories, ignore_metadata, types_mapper)
#     816     _check_data_column_metadata_consistency(all_columns)
#     817     columns = _deserialize_column_index(table, all_columns, column_indexes)
# --> 818     blocks = _table_to_blocks(options, table, categories, ext_columns_dtypes)
#     819
#     820     axes = [columns, index]
#
# ~/anaconda3/envs/fastai/lib/python3.9/site-packages/pyarrow/pandas_compat.py in _table_to_blocks(options, block_table, categories, extension_columns)
#    1166     # Convert an arrow table to Block from the internal pandas API
#    1167     columns = block_table.column_names
# -> 1168     result = pa.lib.table_to_blocks(options, block_table, categories,
#    1169                                     list(extension_columns.keys()))
#    1170     return [_reconstruct_block(item, columns, extension_columns)
#
# KeyboardInterrupt:

# %%
train.cnt_partial_nulls.value_counts()

# %% [markdown]
# ## Answer

# %% [markdown]
# Yes, `x`, `y` & `z` either all have values or none do

# %% [markdown]
# # Are all landmarks whenever any landmark is populated in a frame by type?
#
# We know that sometimes a frame only contains a certain type (e.g. there's a left hand but no right hand).
#
# However; if there's a type (e.g. a left hand) in the frame, does that mean all landmarks have data?

# %%
n = len(train)
for i in tqdm(range(n)):
    record = train.iloc[i]
    record_id = str(record['participant_id']) + '_' + str(record['sequence_id'])

    pq_path = path / record['path']
    try:
        landmarks = pd.read_parquet(pq_path)
    except OSError:
            pass
    else: 
        cnt_partial_nulls_by_frame = (landmarks.assign(has_coords=lambda x: (~x[COORD_COLS].isna()).all(axis=1))
                                      .loc[:, ['frame', 'type', 'landmark_index', 'has_coords']]
                                      .groupby(['type', 'frame'])
                                      .apply(lambda g: (~g.has_coords.all() & g.has_coords.any()).sum())
                                      ).sum()
        train.loc[record_id, 'cnt_partial_nulls_by_frame'] = cnt_partial_nulls_by_frame
# Out:
#   0%|          | 0/94477 [00:00<?, ?it/s]

# %%
train.cnt_partial_nulls_by_frame.value_counts()
# Out:
# 0.0    94477
# Name: cnt_partial_nulls_by_frame, dtype: int64

# %% [markdown]
# ## Answer

# %% [markdown]
# Yes, whenever a frame has a type in it (e.g. a right hand), all landmarks have data.

# %% [markdown]
# # Frames Summary
#
# We know there are a different number of frames by type in each record. How many frames are in each on average?
#
# How many frames per type (e.g. left hand, right hand, pose and face)?

# %%
n = len(train)
for i in tqdm(range(n)):
    record = train.iloc[i]
    record_id = str(record['participant_id']) + '_' + str(record['sequence_id'])

    pq_path = path / record['path']
    try:
        landmarks = pd.read_parquet(pq_path)
    except OSError:
            pass
    else:
        train.loc[record_id, 'total_frames'] = landmarks.frame.nunique()
        
        type_frame_cnts = (landmarks.assign(has_coords=lambda x: ~x[COORD_COLS].isna().all(axis=1))
         .loc[:, ['frame', 'type', 'landmark_index', 'has_coords']]
         .groupby(['type', 'frame'], as_index=False)
         [['has_coords']]
         .all()
         .groupby('type')
         .has_coords
         .sum()
         .rename('cnt_frames')
        )


        train.loc[record_id, ['face', 'left_hand', 'pose', 'right_hand']] = type_frame_cnts.sort_index().tolist()
# Out:
#   0%|          | 0/94477 [00:00<?, ?it/s]

# %% [markdown]
# # Save Meta Data

# %%
train.to_csv(path / 'train_with_meta.csv')

# %% [markdown]
# # Sign Summary

# %%
train = pd.read_csv(path / 'train_with_meta.csv')

# %%
POSES = ['face', 'left_hand', 'pose', 'right_hand']
g = train.groupby(['sign'])
medians = (g[POSES + ['total_frames']]
           .median()
           .rename(columns=lambda x: x + '_median')
          )

means = (g[POSES + ['total_frames']]
         .mean()
         .rename(columns=lambda x: x + '_mean')
        )

percent_zeros = (g[POSES]
                 .apply(lambda g: (g <= 0).sum() / g.size)
                 .rename(columns=lambda x: x + '_percent_zeros')
                )

frames = [medians, means, percent_zeros]
sign_summary = (pd.concat(frames, axis=1)
                .sort_index(axis=1)
               )

sign_summary.to_excel('Sign Summary.xlsx')

sign_summary
# Out:
#            face_mean  face_median  face_percent_zeros  left_hand_mean  \
# sign
# TV         36.755844         22.0                 0.0       13.641558
# after      30.181556         16.0                 0.0        7.521614
# airplane   43.633588         27.0                 0.0       15.526718
# all        35.981865         20.0                 0.0        8.227979
# alligator  45.297436         26.0                 0.0       12.433333
# ...              ...          ...                 ...             ...
# yesterday  39.346734         23.0                 0.0       11.723618
# yourself   34.924675         18.0                 0.0       11.046753
# yucky      37.377309         23.0                 0.0       11.709763
# zebra      38.354667         23.0                 0.0        9.458667
# zipper     32.561873         17.0                 0.0        6.899666
#
#            left_hand_median  left_hand_percent_zeros  pose_mean  pose_median  \
# sign
# TV                      0.0                 0.135714  36.875325         22.0
# after                   0.0                 0.140490  30.391931         16.0
# airplane                0.0                 0.138677  43.954198         27.0
# all                     0.0                 0.137953  36.502591         21.0
# alligator               0.0                 0.135256  46.207692         27.0
# ...                     ...                      ...        ...          ...
# yesterday               0.0                 0.148241  39.459799         23.0
# yourself                0.0                 0.138961  35.062338         18.0
# yucky                   0.0                 0.141821  37.440633         23.0
# zebra                   0.0                 0.140000  38.397333         23.0
# zipper                  0.0                 0.131271  32.608696         17.0
#
#            pose_percent_zeros  right_hand_mean  right_hand_median  \
# sign
# TV                        0.0        10.981818                3.0
# after                     0.0         6.613833                2.0
# airplane                  0.0        15.290076                7.0
# all                       0.0         9.839378                4.0
# alligator                 0.0        11.466667                4.0
# ...                       ...              ...                ...
# yesterday                 0.0        15.472362               10.0
# yourself                  0.0        10.301299                4.0
# yucky                     0.0        13.195251                5.0
# zebra                     0.0        12.762667                5.0
# zipper                    0.0         7.096990                2.0
#
#            right_hand_percent_zeros  total_frames_mean  total_frames_median
# sign
# TV                         0.106494          36.875325                 22.0
# after                      0.095821          30.391931                 16.0
# airplane                   0.098601          43.954198                 27.0
# all                        0.092617          36.502591                 21.0
# alligator                  0.101923          46.207692                 27.0
# ...                             ...                ...                  ...
# yesterday                  0.094849          39.459799                 23.0
# yourself                   0.099351          35.062338                 18.0
# yucky                      0.094327          37.440633                 23.0
# zebra                      0.092000          38.397333                 23.0
# zipper                     0.101171          32.608696                 17.0
#
# [250 rows x 14 columns]

# %% [markdown]
# # Participant Summary

# %%
POSES = ['face', 'left_hand', 'pose', 'right_hand']
g = train.groupby(['participant_id'])
medians = (g[POSES + ['total_frames']]
           .median()
           .rename(columns=lambda x: x + '_median')
          )

means = (g[POSES + ['total_frames']]
         .mean()
         .rename(columns=lambda x: x + '_mean')
        )

percent_zeros = (g[POSES]
                 .apply(lambda g: (g <= 0).sum() / g.size)
                 .rename(columns=lambda x: x + '_percent_zeros')
                )

frames = [medians, means, percent_zeros]
sign_summary = (pd.concat(frames, axis=1)
                .sort_index(axis=1)
               )

sign_summary.to_excel('Sign Summary.xlsx')

sign_summary
# Out:
#                 face_mean  face_median  face_percent_zeros  left_hand_mean  \
# participant_id
# 2044            15.608108         15.0            0.000000        0.005613
# 4718            36.810517         21.0            0.000143        0.179766
# 16069           44.900165         25.0            0.000000       25.479167
# 18796           34.588806         14.0            0.000000        0.012564
# 22343           43.026085         26.0            0.000000       23.368399
# 25571           19.161190         12.0            0.000000        0.127296
# 26734           45.113613         30.0            0.000000        0.023755
# 27610           53.675789         30.0            0.000175       25.045614
# 28656           51.427350         30.0            0.000000        3.587990
# 29302           37.285684         33.0            0.000000        5.124100
# 30680           16.440084         10.0            0.001423        0.008089
# 32319           34.264675         26.0            0.000000       21.861772
# 34503           61.464686         51.0            0.000000       37.819802
# 36257           39.191789         20.0            0.000000       21.678922
# 37055           27.753442         22.0            0.000000        9.716867
# 37779            9.919699          9.5            0.000000        0.000209
# 49445           66.156200         43.0            0.000050        0.252214
# 53618           28.227448         16.0            0.000054        2.051332
# 55372           36.066308         22.0            0.000000       24.400332
# 61333           54.771224         30.0            0.000000       30.715102
# 62590           25.240193         18.0            0.000000        0.041639
#
#                 left_hand_median  left_hand_percent_zeros  pose_mean  \
# participant_id
# 2044                         0.0                 0.249168  15.613098
# 4718                         0.0                 0.241426  36.967705
# 16069                       15.0                 0.000103  44.906766
# 18796                        0.0                 0.249072  34.631354
# 22343                       16.0                 0.005131  43.045970
# 25571                        0.0                 0.247865  19.179560
# 26734                        0.0                 0.246230  45.117538
# 27610                       16.0                 0.045322  55.287719
# 28656                        0.0                 0.228468  51.430638
# 29302                        0.0                 0.128653  37.289072
# 30680                        0.0                 0.248352  18.097364
# 32319                       18.0                 0.000368  34.271408
# 34503                       24.0                 0.001320  61.546095
# 36257                       14.0                 0.000000  39.312704
# 37055                        3.0                 0.106175  27.778614
# 37779                        0.0                 0.249948   9.920117
# 49445                        0.0                 0.236161  67.807568
# 53618                        0.0                 0.218911  28.235610
# 55372                       17.0                 0.000052  36.188769
# 61333                       21.0                 0.045816  54.782041
# 62590                        0.0                 0.248904  25.444225
#
#                 pose_median  pose_percent_zeros  right_hand_mean  \
# participant_id
# 2044                   15.0                 0.0        11.269231
# 4718                   21.0                 0.0        19.520149
# 16069                  25.0                 0.0         0.088078
# 18796                  14.0                 0.0        23.170474
# 22343                  26.0                 0.0         0.556767
# 25571                  12.0                 0.0        12.384994
# 26734                  30.0                 0.0        28.730428
# 27610                  31.0                 0.0         4.993918
# 28656                  30.0                 0.0        30.722989
# 29302                  33.0                 0.0        15.077298
# 30680                  12.0                 0.0         9.991612
# 32319                  26.0                 0.0         0.105828
# 34503                  51.0                 0.0         0.288669
# 36257                  20.0                 0.0         0.004289
# 37055                  22.0                 0.0         7.253012
# 37779                   9.5                 0.0         8.089502
# 49445                  44.0                 0.0        34.079710
# 53618                  16.0                 0.0        16.938574
# 55372                  22.0                 0.0         0.044136
# 61333                  30.0                 0.0         5.924898
# 62590                  18.0                 0.0        20.875740
#
#                 right_hand_median  right_hand_percent_zeros  \
# participant_id
# 2044                         11.0                  0.000000
# 4718                         11.0                  0.003572
# 16069                         0.0                  0.246493
# 18796                        11.0                  0.000000
# 22343                         0.0                  0.239309
# 25571                         9.0                  0.001488
# 26734                        22.0                  0.000103
# 27610                         0.0                  0.201170
# 28656                        16.0                  0.010574
# 29302                        12.0                  0.002594
# 30680                         7.0                  0.000300
# 32319                         0.0                  0.240532
# 34503                         0.0                  0.232508
# 36257                         0.0                  0.249234
# 37055                         0.0                  0.137425
# 37779                         8.0                  0.000000
# 49445                        22.0                  0.000201
# 53618                        10.0                  0.030445
# 55372                         0.0                  0.243939
# 61333                         0.0                  0.198520
# 62590                        15.0                  0.000548
#
#                 total_frames_mean  total_frames_median
# participant_id
# 2044                    15.613098                 15.0
# 4718                    36.967705                 21.0
# 16069                   44.906766                 25.0
# 18796                   34.631354                 14.0
# 22343                   43.045970                 26.0
# 25571                   19.179560                 12.0
# 26734                   45.117538                 30.0
# 27610                   55.287719                 31.0
# 28656                   51.430638                 30.0
# 29302                   37.289072                 33.0
# 30680                   18.097364                 12.0
# 32319                   34.271408                 26.0
# 34503                   61.546095                 51.0
# 36257                   39.312704                 20.0
# 37055                   27.778614                 22.0
# 37779                    9.920117                  9.5
# 49445                   67.807568                 44.0
# 53618                   28.235610                 16.0
# 55372                   36.188769                 22.0
# 61333                   54.782041                 30.0
# 62590                   25.444225                 18.0
